# %% [markdown]
# <a href="https://colab.research.google.com/github/LucaoCode/Exercicios_Faculdade/blob/main/Introdu%C3%A7%C3%A3o_Algoritimos/Exercicio_de_Algoritimos_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **<H1>Lista de Exercicios de algoritimos 2**

# %% [markdown]
# ![ex1.png](data:image/png;base64,...)

# %%
#pela Logica
horas_mes = int(input("Horas trabalhadas no mês >> "))
salario_hora = float(input("Digite o Valor da sua hora de trabalho R$"))
horas_extras = horas_mes - 160
teve_hora_extra = int(horas_extras > 0)

salario_total = salario_hora * horas_mes + (horas_extras*salario_hora * 1.5)
print('Seu salario é R$', str(salario_total))
# Out:
# Horas trabalhadas no mês >> 190
# Digite o Valor da sua hora de trabalho R$34
# Seu salario é R$ 7990.0

# %%
#Por if e else
horas_mes = int(input("Horas trabalhadas no mês >> "))
salario_hora = float(input("Digite o Valor da sua hora de trabalho R$"))
horas_extras = horas_mes - 160
salario_total = salario_hora*horas_mes
salario_total_extras = (horas_extras*salario_hora*1.5) + salario_total

if horas_extras > 0:
  print("Seu Salario tem horas extras" , str(salario_total_extras))
else:
  print("Seu Salario tem horas extras" , str(salario_total))
# Out:
# Horas trabalhadas no mês >> 190
# Digite o Valor da sua hora de trabalho R$34
# Seu Salario tem horas extras 7990.0

# %% [markdown]
# ![ex1.png](data:image/png;base64,...)

# %%
nome = input('Digite seu nome >> ')
altura = float(input('Digite sua altura>> '))
sexo = input('Digite seu sexo M ou F >> ')

if sexo == 'M' :
  print("Seu peso masculino é >> " , str((72.7 * altura)- 58))
elif sexo == "F" :
  print("Seu peso feminino é >> " , str((62.1*altura) - 54))
else:
  print("Inválido")
# Out:
# Digite seu nome >> Lucas
# Digite sua altura>> 1.50
# Digite seu sexo M ou F >> M
# Seu peso masculino é >>  51.05000000000001

# %% [markdown]
# ![ex1.png](data:image/png;base64,...)

# %%
livros_comprados = int(input("Quantidade de livros comprados >>> "))

if livros_comprados == 0:
  print("Vocé comporou 0 livros, você tem 0 pontos")
elif livros_comprados == 1:
  print("Vocé comporou 1 livros, você tem 5 pontos")
elif livros_comprados == 2:
  print("Vocé comporou 2 livros, você tem 15 pontos")
elif livros_comprados == 3:
  print("Vocé comporou 3 livros, você tem 30 pontos")
elif livros_comprados == 4:
  print("Vocé comporou 4 livros, você tem 60 pontos")
# Out:
# Quantidade de livros comprados >>> 4
# Vocé comporou 4 livros, você tem 60 pontos

# %% [markdown]
# ![ex1.png](data:image/png;base64,...)

# %%
N1 = int(input("Digite sua N1 >> "))
N2 = int(input("Digite sua N2 >> "))
N3 = int(input("Digite sua N3 >> "))
p1 = 2
p2 = 3
p3 = 5

resultado = (N1*p1 + N2*p2 + N3*p3)/(p1+p2+p3)
print("Sua nota é >> ", str(resultado))
# Out:
# Digite sua N1 >> 10
# Digite sua N2 >> 10
# Digite sua N3 >> 9
# Sua nota é >>  9.5

# %% [markdown]
# ![ex1.png](data:image/png;base64,...)

# %%
c = float(input("Digite o capital >> "))
i = float(input("Digite a taxa de juros >> "))
n = int(input("Digite o numero de periodos >> "))

j = c * (1+ i)**n - 1
print("Seus rendimentos >> ", str(j))
# Out:
# Digite o capital >> 10
# Digite a taxa de juros >> 10
# Digite o numero de periodos >> 2
# Seus rendimentos >>  1209.0
